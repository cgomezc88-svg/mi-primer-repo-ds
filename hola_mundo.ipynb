# %%
print("Hola mundo desde mi primer Notebook")
# Out:
# Hola mundo desde mi primer Notebook

# %%
import matplotlib.pyplot as plt
# Datos de prueba: Meses y ventas hipotéticas
meses = ['Enero', 'Febrero', 'Marzo', 'Abril', 'Mayo']
ventas = [150, 200, 250, 300, 350]
plt.plot(meses, ventas, marker='o', linestyle='--', color='b')
plt.title('Ventas Mensuales')
plt.xlabel('Meses')
plt.ylabel('Ventas')
plt.grid(True)
plt.show()
